# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# Bananas are healthier than lollipops.
#
# 1) Bananas: 7/10 - Good nutrients (potassium, fiber, vitamins); natural sugars but balanced.
# 2) Lollipop: 1/10 - Mostly added sugar; negligible nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Which foods should apples be compared against? Please list the other items. If you’d like, I can compare apples with bananas, oranges, and carrots.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session =session
)
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-rich: potassium, fiber, vitamin C; healthy snack when eaten with portion control
# 2) Lollipop: 2/10 - Mostly sugar with little to no nutrients; can spike blood sugar and affect teeth

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session = session
    )

print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-rich: potassium, fiber, vitamin C; healthy with portion control
# 2) Apples: 7/10 - Good fiber and vitamins; lower calories than bananas but slightly less potassium
# 3) Lollipop: 2/10 - Mostly sugar with little to no nutrients; can spike blood sugar and affect teeth
